# %% [markdown]
# <a href="https://colab.research.google.com/github/Raniamea/arabic-video-summarisation/blob/main/notebooks/02_scenedetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.25.2 --force-reinstall --no-cache-dir
# !pip install pillow opencv-python opencv-contrib-python
# !pip install git+https://github.com/Breakthrough/PySceneDetect.git@v0.6
# !pip install torch==2.0.1+cu118 torchaudio==2.0.2 torchvision==0.15.2 --index-url https://download.pytorch.org/whl/cu118
# !pip install transformers==4.35.2 sentencepiece accelerate

# %%
try:
    import scenedetect
except Exception:
    # !pip -q install "scenedetect>=0.6,<0.7"

try:
    import sentence_transformers
except Exception:
    # !pip -q install "sentence-transformers>=2.2,<2.7"

# %%
# --- Imports
import os, json, random, re
import numpy as np
import torch
import cv2
from PIL import Image

# --- Reproducibility (deterministic decoding across runs/devices)
random.seed(0); np.random.seed(0)
torch.manual_seed(0)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(0)

# %%
from google.colab import drive
import os

# Unmount first
# !fusermount -u /content/drive || echo "Already unmounted"

# Delete the mount folder entirely
# !rm -rf /content/drive

# Now mount again
from google.colab import drive
drive.mount('/content/drive')
# Out:
# fusermount: failed to unmount /content/drive: No such file or directory
# Already unmounted
# Mounted at /content/drive

# %%
from transformers import AutoProcessor, Blip2ForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
from transformers import CLIPProcessor, CLIPModel
from sentence_transformers import SentenceTransformer, util
import torch

# Device
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Vision/Text device:", device)

# BLIP-2 (EN captioning) — stays on GPU via device_map
caption_processor = AutoProcessor.from_pretrained("Salesforce/blip2-opt-2.7b", use_fast=False)
caption_model = Blip2ForConditionalGeneration.from_pretrained(
    "Salesforce/blip2-opt-2.7b",
    device_map="auto",
    torch_dtype=torch.float16 if device == "cuda" else torch.float32,
)

def resolve_lang_id(tokenizer, lang_code: str) -> int:
    if hasattr(tokenizer, "lang_code_to_id"):
        return tokenizer.lang_code_to_id[lang_code]
    if hasattr(tokenizer, "get_lang_id"):
        return tokenizer.get_lang_id(lang_code)
    if hasattr(tokenizer, "lang_code_to_token"):
        tok = tokenizer.lang_code_to_token[lang_code]
        tid = tokenizer.convert_tokens_to_ids(tok)
        if tid != tokenizer.unk_token_id:
            return tid
    for cand in (f"__{lang_code}__", f"<<{lang_code}>>", lang_code):
        tid = tokenizer.convert_tokens_to_ids(cand)
        if tid != tokenizer.unk_token_id:
            return tid
    raise RuntimeError(f"Could not resolve language id for: {lang_code}")

# NLLB-200 (EN -> AR) — keep on CPU to avoid GPU OOM
TRANS_DEVICE = "cpu"
nllb_model_name = "facebook/nllb-200-distilled-600M"
translator_tokenizer = AutoTokenizer.from_pretrained(nllb_model_name, src_lang="eng_Latn")
translator_model = AutoModelForSeq2SeqLM.from_pretrained(nllb_model_name).to(TRANS_DEVICE)
forced_bos_token_id = resolve_lang_id(translator_tokenizer, "arb_Arab")
print("NLLB-200 loaded on CPU. forced_bos_token_id:", forced_bos_token_id)

# CLIP for image<->EN text grounding — keep on GPU if available
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32").to(device)

print("Models ready.")
# Out:
# Vision/Text device: cuda
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/882 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/10.0G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/141 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# NLLB-200 loaded on CPU. forced_bos_token_id: 256011
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# Models ready.

# %%
# --- Paths & params
base_path = "/content/drive/MyDrive/ArabicVideoSummariser"
videos_path = os.path.join(base_path, "videos")
captions_path = os.path.join(base_path, "captions")
keyframes_path = os.path.join(base_path, "keyframes")
transcripts_path = os.path.join(base_path, "transcripts")

os.makedirs(captions_path, exist_ok=True)
os.makedirs(keyframes_path, exist_ok=True)

# Read params.json (must contain: {"video_file": "..."} )
param_path = os.path.join(base_path, "params.json")
with open(param_path, "r", encoding="utf-8") as f:
    params = json.load(f)

video_filename = params.get("video_file")
video_filename = "WisaWasef.mp4"
assert video_filename, "params.json must include 'video_file'."
video_path = os.path.join(videos_path, video_filename)
assert os.path.exists(video_path), f"Video not found: {video_path}"

video_name = os.path.splitext(video_filename)[0]
keyframe_dir = os.path.join(keyframes_path, video_name)
os.makedirs(keyframe_dir, exist_ok=True)

captions_json_path = os.path.join(captions_path, f"{video_name}.json")

print(f"Processing video file: {video_filename}")
# Out:
# Processing video file: WisaWasef.mp4

# %%
import re
from PIL import Image
import cv2
import numpy as np

timecode_re = re.compile(r"\[(\d+(?:\.\d+)?)\s*-\s*(\d+(?:\.\d+)?)\]\s+(.*)")

def grab_frames_around(cap: cv2.VideoCapture, fps: float, base_time_s: float, offsets=(0.0, 0.2, 0.4)):
    """Return list of PIL images at base_time_s + offsets (seconds)."""
    images = []
    for off in offsets:
        t = max(0.0, base_time_s + off)
        frame_idx = int(t * fps)
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
        ok, fr = cap.read()
        if ok:
            images.append(Image.fromarray(cv2.cvtColor(fr, cv2.COLOR_BGR2RGB)))
    return images

@torch.no_grad()
def blip2_nbest_en(images, beams=5, returns=3):
    """Generate N-best English captions across multiple images (deterministic)."""
    cands = []
    for img in images:
        inputs = caption_processor(images=[img], return_tensors="pt", padding=True)\
                 .to(device, torch.float16 if device=="cuda" else torch.float32)
        ids = caption_model.generate(
            **inputs,
            do_sample=False,
            num_beams=beams,
            num_return_sequences=returns,
            length_penalty=1.0,
            repetition_penalty=1.05,
            no_repeat_ngram_size=3,
            max_new_tokens=50,
        )
        for seq in ids:
            txt = caption_processor.decode(seq, skip_special_tokens=True).strip()
            cands.append(txt)
    seen, uniq = set(), []
    for t in cands:
        if t not in seen:
            seen.add(t); uniq.append(t)
    return uniq

@torch.no_grad()
def mt_nbest_ar(en_list, beams=4, returns=2):
    """Translate EN candidates to Arabic using NLLB on CPU; return unique (en, ar) pairs."""
    pairs, seen = [], set()
    for en in en_list:
        ti = translator_tokenizer([en], return_tensors="pt", padding=True).to(TRANS_DEVICE)
        out = translator_model.generate(
            **ti,
            do_sample=False,                 # deterministic
            num_beams=beams,
            num_return_sequences=returns,    # smaller to keep CPU fast
            max_new_tokens=64,
            no_repeat_ngram_size=3,
            repetition_penalty=1.15,
            forced_bos_token_id=forced_bos_token_id,  # Arabic output
        )
        for seq in out:
            ar = translator_tokenizer.decode(seq, skip_special_tokens=True).strip()
            key = (en, ar)
            if key not in seen:
                seen.add(key); pairs.append(key)
    return pairs

@torch.no_grad()
def clip_image_text_score(image_pil: Image.Image, text_en: str) -> float:
    """Cosine similarity between image and EN caption using CLIP."""
    inputs = clip_processor(text=[text_en], images=image_pil, return_tensors="pt", padding=True).to(device)
    outs = clip_model(**inputs)
    img = outs.image_embeds / outs.image_embeds.norm(dim=-1, keepdim=True)
    txt = outs.text_embeds / outs.text_embeds.norm(dim=-1, keepdim=True)
    return float((img @ txt.T).squeeze().detach().cpu())

# %%
# Scene detection (PySceneDetect)
from scenedetect import open_video, SceneManager
from scenedetect.detectors import ContentDetector

# Detect scenes
scene_manager = SceneManager()
scene_manager.add_detector(ContentDetector(threshold=30.0))
video = open_video(video_path)
scene_manager.detect_scenes(video)
scene_list = scene_manager.get_scene_list()

# VideoCapture for frame access
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS) or 25.0

print(f"Detected {len(scene_list)} scenes, FPS={fps:.2f}")
# Out:
# INFO:pyscenedetect:Downscale factor set to 7, effective resolution: 274 x 154
# Detected 70 scenes, FPS=25.00

# %%
# ===== captioning & Visual-grounding re-ranking =====
import os, json, cv2, numpy as np
from PIL import Image

# Container for results
captions = {}

# Hyperparameters (keep consistent with main run for fair comparison)
frame_offsets = (0.0,  0.2,  0.4)   # multi-frame sampling around scene start
beams_caption, returns_caption = 5, 3
beams_mt, returns_mt = 4, 2       # translate best EN for parity (not used for scoring)
save_keyframes = True

for i, (start, _) in enumerate(scene_list):
    scene_t = start.get_seconds()

    # 1) Multi-frame sampling around the same scene boundry
    images = grab_frames_around(cap, fps, scene_t, offsets=frame_offsets)
    if not images:
        print(f" Scene {i:03} has no decodable frames; skipping.")
        continue

    # Save representative keyframe (first sampled image)
    frame_name = f"scene_{i:03}.jpg"
    if save_keyframes:
        frame_path = os.path.join(keyframe_dir, frame_name)
        cv2.imwrite(frame_path, cv2.cvtColor(np.array(images[0]), cv2.COLOR_RGB2BGR))

    # 2) English N-best captions across frames with deterministic decoding
    en_cands = blip2_nbest_en(images, beams=beams_caption, returns=returns_caption)
    if not en_cands:
        print(f"No EN candidates for scene {i:03}; skipping.")
        continue

    # 3) Visual grounding: average CLIP score across sampled frames
    en_vis = {en: float(np.mean([clip_image_text_score(img, en) for img in images])) for en in en_cands}

    # 4) Pick best English by visual score
    best_en = max(en_vis.keys(), key=lambda t: en_vis[t])
    best_vscore = en_vis[best_en]

    # 5) Translate best EN (N-best) for Arabic output
    pair_cands = mt_nbest_ar([best_en], beams=beams_mt, returns=returns_mt)
    if pair_cands:
        # Prefer the first Arabic for the chosen EN
        cand_for_best_en = [ar for (en, ar) in pair_cands if en == best_en]
        best_ar = cand_for_best_en[0] if cand_for_best_en else pair_cands[0][1]
    else:
        best_ar = ""

    # 6) Save visually validated result
    captions[frame_name] = {
        "scene_time": round(scene_t, 2),
        "english": best_en,
        "arabic": best_ar,
        "scores": {"visual": round(best_vscore, 4)},
    }

    print(f"✓ {frame_name} @ {scene_t:.2f}s | EN*: {best_en} | AR: {best_ar} | V={best_vscore:.3f}")

cap.release()

with open(captions_json_path, "w", encoding="utf-8") as f:
    json.dump(captions, f, ensure_ascii=False, indent=2)

print(f"Captions saved to: {captions_json_path}")
print(f"Keyframes dir: {keyframe_dir}")
# Out:
# ✓ scene_000.jpg @ 0.00s | EN*: an image of a painting on a black background | AR: صورة لوحة على خلفية سوداء | V=0.260
# ✓ scene_001.jpg @ 5.28s | EN*: a close up of a person's hand holding a piece of fabric | AR: مقربة من يد شخص يحمل قطعة من النسيج | V=0.278
# ✓ scene_002.jpg @ 21.16s | EN*: a woman wearing a headscarf sits in a room | AR: امرأة ترتدي حجاباً تجلس في غرفة | V=0.285
# ✓ scene_003.jpg @ 23.08s | EN*: a woman in a black headscarf sitting in front of a mirror | AR: امرأة في حجاب أسود تجلس أمام المرآة | V=0.306
# ✓ scene_004.jpg @ 26.76s | EN*: an indian man is working on a loom in his home | AR: رجل هندي يعمل على طلاء في منزله | V=0.323
# ✓ scene_005.jpg @ 32.28s | EN*: a woman in a hijab is working on a rug | AR: امرأة في الحجاب تعمل على السجادة | V=0.298
# ✓ scene_006.jpg @ 35.68s | EN*: an alley lined with trees in the middle of a desert | AR: زقاق من الأشجار في منتصف الصحراء | V=0.278
# ✓ scene_007.jpg @ 36.56s | EN*: an alleyway lined with trees in the middle of a desert | AR: زقاق من الأشجار في منتصف الصحراء | V=0.286
# ✓ scene_008.jpg @ 37.16s | EN*: there is a sign on the gate that says welcome to the oasis | AR: هناك علامة على البوابة تقول مرحباً بكم في الأوعية | V=0.266
# ✓ scene_009.jpg @ 43.08s | EN*: ramse wassef art center | AR: مركز الفن رامس واصف | V=0.404
# ✓ scene_010.jpg @ 45.88s | EN*: an elderly man sitting in front of a wall of tapestries | AR: رجل عجوز يجلس أمام جدار من السجاد | V=0.302
# ✓ scene_011.jpg @ 50.08s | EN*: a framed picture of a man with glasses on the wall | AR: صورة مدرجة لرجل يرتدي نظارات على الحائط | V=0.309
# ✓ scene_012.jpg @ 56.36s | EN*: an archway with a green wall and a painting on it | AR: قوس مع جدار أخضر ولوحة عليه | V=0.265
# ✓ scene_013.jpg @ 65.08s | EN*: a bird is sitting on the ground near some bushes | AR: طائر يجلس على الأرض بالقرب من بعض الشجيرات | V=0.326
# ✓ scene_014.jpg @ 66.52s | EN*: an archway in the middle of a desert with a quote on it | AR: قوس في منتصف الصحراء مع اقتباس عليه | V=0.346
# ✓ scene_015.jpg @ 69.40s | EN*: the sun is shining in a blue sky | AR: الشمس تشرق في السماء الزرقاء | V=0.274
# ✓ scene_016.jpg @ 73.88s | EN*: a rug with writing on it hanging on a wall | AR: سجادة مكتوبة عليها معلقة على الحائط | V=0.328
# ✓ scene_017.jpg @ 75.56s | EN*: a man is working on a loom in a small room | AR: رجل يعمل على طلاء في غرفة صغيرة | V=0.287
# ✓ scene_018.jpg @ 79.76s | EN*: an elderly man sitting in front of a wall of tapestries | AR: رجل عجوز يجلس أمام جدار من السجاد | V=0.283
# ✓ scene_019.jpg @ 87.84s | EN*: an old photo of an indian man with glasses and a quote | AR: صورة قديمة لرجل هندي ذو نظارات و اقتباس | V=0.348
# ✓ scene_020.jpg @ 92.40s | EN*: a narrow alley in the middle of an old building | AR: زقاق ضيق في منتصف مبنى قديم | V=0.252
# ✓ scene_021.jpg @ 102.88s | EN*: a group of people are gathered around a tree and a bird is flying above them | AR: مجموعة من الناس تجمع حول شجرة وتطير طائر فوقهم | V=0.285
# ✓ scene_022.jpg @ 110.24s | EN*: an indian man is working on a loom in a small room | AR: رجل هندي يعمل على طلاء في غرفة صغيرة | V=0.324
# ✓ scene_023.jpg @ 121.60s | EN*: a person is using a brush to paint on a large tapestry | AR: شخص يستخدم فرشاة لطلاء على نسيج كبير | V=0.344
# ✓ scene_024.jpg @ 124.16s | EN*: a woman is weaving a rug on a loom in front of a window | AR: امرأة تنسج سجادة على طلاء أمام النافذة | V=0.321
# ✓ scene_025.jpg @ 125.76s | EN*: a person sitting on a wooden bench with a stuffed animal on it | AR: شخص يجلس على مقعد خشبي مع حيوان ملابس عليه | V=0.266
# ✓ scene_026.jpg @ 128.80s | EN*: a woman wearing a headscarf is working on a piece of fabric | AR: امرأة ترتدي حجاباً تعمل على قطعة من النسيج | V=0.275
# ✓ scene_027.jpg @ 130.96s | EN*: the woman is standing in front of a bench | AR: المرأة تقف أمام مقعد | V=0.262
# ✓ scene_028.jpg @ 134.80s | EN*: an older man with a moustache is holding a piece of fabric | AR: رجل عجوز ذو شارب يحمل قطعة من النسيج | V=0.350
# ✓ scene_029.jpg @ 138.20s | EN*: an older man is holding a piece of fabric in front of a painting | AR: رجل عجوز يحمل قطعة من النسيج أمام لوحة | V=0.332
# ✓ scene_030.jpg @ 144.24s | EN*: a woman in a hijab is working on a rug | AR: امرأة في الحجاب تعمل على السجادة | V=0.317
# ✓ scene_031.jpg @ 147.04s | EN*: a man is working on a loom in a small room | AR: رجل يعمل على طلاء في غرفة صغيرة | V=0.295
# ✓ scene_032.jpg @ 158.96s | EN*: a person is using a loom to weave a large piece of fabric | AR: شخص يستخدم خياطة للنسجة قطعة كبيرة من النسيج | V=0.350
# ✓ scene_033.jpg @ 165.36s | EN*: a tapestry hanging on the wall with people and animals | AR: نسيج معلق على الحائط مع الناس والحيوانات | V=0.309
# ✓ scene_034.jpg @ 170.48s | EN*: two women are sitting in a room with a mirror | AR: إمرأتان جالسان في غرفة مع مرآة | V=0.243
# ✓ scene_035.jpg @ 176.44s | EN*: a close up of a person working on a tapestry | AR: مقربة من شخص يعمل على السجاد | V=0.326
# ✓ scene_036.jpg @ 180.32s | EN*: a woman in a black headscarf is sitting on the floor | AR: امرأة في حجاب رئيسي أسود تجلس على الأرض | V=0.275
# ✓ scene_037.jpg @ 185.16s | EN*: a man in a white lab coat is weaving something on a loom | AR: رجل في معطف مختبر أبيض ينسج شيئًا على خيط | V=0.284
# ✓ scene_038.jpg @ 188.96s | EN*: a woman wearing a headscarf smiles as she works on a rug | AR: امرأة ترتدي حجابا تبتسم بينما تعمل على السجاد | V=0.314
# ✓ scene_039.jpg @ 193.08s | EN*: a person using a loom to weave yarn on a wall | AR: شخص يستخدم القماش لتنسيق الخيط على الحائط | V=0.359
# ✓ scene_040.jpg @ 193.88s | EN*: a person using a loom to weave a piece of fabric | AR: شخص يستخدم القماش لترقية قطعة من النسيج | V=0.360
# ✓ scene_041.jpg @ 194.84s | EN*: a man with a moustache sitting in front of a wall of tapestries | AR: رجل ذو شارب يجلس أمام جدار من السجاد | V=0.295
# ✓ scene_042.jpg @ 199.04s | EN*: a man in a white shirt and yellow gloves is smiling | AR: رجل في قميص أبيض و قفازات صفراء يبتسم | V=0.278
# ✓ scene_043.jpg @ 202.68s | EN*: there is a man standing in front of a white curtain | AR: هناك رجل يقف أمام الستارة البيضاء | V=0.265
# ✓ scene_044.jpg @ 209.60s | EN*: a woman wearing a headscarf is working on a rug | AR: امرأة ترتدي حجاباً تعمل على سجادة | V=0.292
# ✓ scene_045.jpg @ 219.32s | EN*: a woman in a headscarf is weaving a piece of fabric | AR: امرأة في حجاب ينسج قطعة من النسيج | V=0.294
# ✓ scene_046.jpg @ 229.04s | EN*: a woman in a headscarf standing in front of a loom | AR: امرأة في حجاب تقف أمام صناعة الخياطة | V=0.313
# ✓ scene_047.jpg @ 230.40s | EN*: a person sitting on the floor next to a large pile of yarn | AR: شخص يجلس على الأرض بجانب كومة كبيرة من الخيط | V=0.312
# ✓ scene_048.jpg @ 236.44s | EN*: a woman in a black headscarf is holding a stuffed animal | AR: امرأة في غطاء رأس أسود تحتوي على حيوان ملحوظ | V=0.302
# ✓ scene_049.jpg @ 243.72s | EN*: a person is holding a bunch of yarn in their hands | AR: شخص يحمل مجموعة من الخيوط في يديه | V=0.349
# ✓ scene_050.jpg @ 252.32s | EN*: a woman in a black headscarf is eating a piece of fruit in front of a mirror | AR: امرأة في حجاب أسود تأكل قطعة من الفاكهة أمام المرآة | V=0.324
# ✓ scene_051.jpg @ 258.08s | EN*: a woman holding a needle and thread while sitting in front of a quilt | AR: امرأة تحمل إبرة وخيط بينما تجلس أمام بطانية | V=0.303
# ✓ scene_052.jpg @ 262.96s | EN*: an older woman is knitting with a needle and thread | AR: امرأة كبيرة في السن تقوم بالخياطة مع إبرة و خيط | V=0.257
# ✓ scene_053.jpg @ 268.88s | EN*: a close up of a person using a needle to weave a rug | AR: مقربة من شخص يستخدم إبرة لترقية السجادة | V=0.276
# ✓ scene_054.jpg @ 273.04s | EN*: an old man sitting in front of a painting | AR: رجل عجوز يجلس أمام لوحة | V=0.293
# ✓ scene_055.jpg @ 274.36s | EN*: a young girl in a yellow hoodie is smiling at the camera | AR: فتاة صغيرة ترتدي قبعة صفراء تبتسم أمام الكاميرا | V=0.272
# ✓ scene_056.jpg @ 276.24s | EN*: a person in a yellow hoodie is weaving on a loom | AR: شخص يرتدي قميصاً صفراء ينسج على خيط | V=0.269
# ✓ scene_057.jpg @ 278.56s | EN*: a woman in a headscarf is working on a piece of fabric | AR: امرأة في حجاب تعمل على قطعة من النسيج | V=0.272
# ✓ scene_058.jpg @ 282.52s | EN*: a woman is standing in front of an open door | AR: امرأة تقف أمام باب مفتوح | V=0.213
# ✓ scene_059.jpg @ 286.40s | EN*: a woman in a hijab sitting on the floor in a room | AR: امرأة مرتدية الحجاب تجلس على الأرض في غرفة | V=0.267
# ✓ scene_060.jpg @ 292.52s | EN*: many different colors of yarn are on a wooden table | AR: العديد من الألوان المختلفة من الخيط على طاولة خشبية | V=0.328
# ✓ scene_061.jpg @ 294.80s | EN*: a man is working on a loom in a small room | AR: رجل يعمل على طلاء في غرفة صغيرة | V=0.295
# ✓ scene_062.jpg @ 297.40s | EN*: a man in a white robe is working on a piece of yarn | AR: رجل في سترة بيضاء يعمل على قطعة من الخيط | V=0.311
# ✓ scene_063.jpg @ 299.36s | EN*: a woman wearing a headscarf is sitting on a bed | AR: امرأة مرتدية حجاب يجلس على السرير | V=0.276
# ✓ scene_064.jpg @ 303.76s | EN*: an old woman is weaving a piece of fabric | AR: امرأة عجوز تنسج قطعة من النسيج | V=0.314
# ✓ scene_065.jpg @ 306.00s | EN*: a man in white shirt working on something in a room | AR: رجل في قميص أبيض يعمل على شيء في غرفة | V=0.285
# ✓ scene_066.jpg @ 307.28s | EN*: a woman wearing a black headscarf sitting in a bed | AR: امرأة ترتدي حجابًا أسودًا تجلس في السرير | V=0.259
# ✓ scene_067.jpg @ 311.68s | EN*: a basket full of yarn and a radio sitting on the floor | AR: سلة مليئة بالخيوط وراديو جالسا على الأرض | V=0.327
# ✓ scene_068.jpg @ 316.28s | EN*: two women are working on a large piece of fabric | AR: امرأتين تعملان على قطعة كبيرة من النسيج | V=0.267
# ✓ scene_069.jpg @ 324.44s | EN*: arabic text on black background | AR: نص عربي على خلفية سوداء | V=0.336
# Captions saved to: /content/drive/MyDrive/ArabicVideoSummariser/captions/WisaWasef.json
# Keyframes dir: /content/drive/MyDrive/ArabicVideoSummariser/keyframes/WisaWasef
